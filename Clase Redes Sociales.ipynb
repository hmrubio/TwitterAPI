# %% [markdown]
# # <center>Estructura de Datos</center>
# ## <center>Universidad Nacional de Tres de Febrero</center>
# ## <center>Clase 10</center>

# %% [markdown]
# ## Redes Sociales

# %% [markdown]
# <center>
#     <h1>Twitter</h1>
#     <a href="https://about.twitter.com/es" title="Sobre twitter"><img src="attachment:65ee4e8b-c112-4edc-8739-177d09a0fdad.png" width="100"></a>
# </center>

# %% [markdown]
# Twitter es una red social, un servicio de microblogging que nos permite  enviar mensajes de texto plano de corta longitud, con un máximo de ~~140~~ 280 caracteres (2017), llamados tuits o tweets. Es asimétrico ya que cualquier persona puede seguir a cualquiera dentro de la red, y así recibir notificaciones cada vez que esa persona twitea un mensaje.
# En general las personas siguen a otras personas con las que comparten intereses.
# Se puede pensar que hay un grafo (dirigido) subyacente, un grafo de intereses, donde los nodos son personas y temas; y las aristas son relaciones

# %% [markdown]
# <center>
#     <img src="attachment:f034800a-fc22-441d-9869-14a3069f20e0.png">
# </center>

# %% [markdown]
# <a href="https://help.twitter.com/es/using-twitter/how-to-tweet" title="Más información sobre como tweetear"><h3>Qué es un tweet?</h3></a>
# Un tweet puede contener texto, imagenes, gifs, videos, menciones a otros usuarios (@usuario), etiquetas o hashtags (#etiqueta), links a otros sitios, y se puede geo-referenciar usando Twitter Places.
#
# También hay información sobre la historia del tweet, como cuantos likes y retweets tuvo y cuantas veces fue citado en otro tweet

# %% [markdown]
# <center>
#     <img src="attachment:b413b3ac-46a4-4e94-812a-8bd478156542.png">
#     <img src="attachment:f7b75490-ed60-4ac6-b8f0-603348471023.png">
# </center>

# %% [markdown]
# Es posible interactuar con un tweet a través de ciertas acciones: responder, retwittear, me gusta, compartir
#
#
#
# <center>
#     <a href="https://help.twitter.com/es/using-twitter/mentions-and-replies"> <img src="attachment:2c4f877b-444d-42b2-9be0-dc024a69c310.png" title="Más información sobre menciones y respuestas"></a>
# </center>

# %% [markdown]
# <center>
#     <img src="attachment:29d1a817-9b9d-43a4-98dc-12aa140dd009.png">
# </center>

# %% [markdown]
# ### Twitter para desarrolladores
# https://developer.twitter.com/en/docs/tools-and-libraries
# #### Twitter API (Application Programming Interface)
# La API de Twitter es un conjunto de herramientas programáticas que pueden utilizarse para interactuar con conversaciones.
#
# #### Twitter Ads API
# Para integrarse  con la plataforma de Twitter Ads (avisos comerciales).
#
# #### Twitter para sitios web
# La suite Twitter for Websites permite incrustar contenido en vivo de Twitter en un sitio web.

# %% [markdown]
# ### Herramientas para acceder a la API de twitter
#
# - <a href="https://github.com/twitterdev/search-tweets-python" >search-tweets-python:</a>  Cliente oficial que soporta la nueva versión v2 de la API de twitter, para uso empresario y premium
# - <a href="https://github.com/twitterdev/search-tweets-python" >twitter:</a>  Librería oficial y minimalista, para la versión v1
# - <a href="https://github.com/geduldig/TwitterAPI" >TwitterAPI:</a> SDK (Software Development Kit) de la comunidad que soporta API v2 y otros accesos como accesos premium
# - <a href="https://python-twitter.readthedocs.io/en/latest/" >python-twitter:</a> Otra librería de la comunidad
#
# Para ver más herramientas: https://developer.twitter.com/en/docs/twitter-api/tools-and-libraries

# %% [markdown]
# ## Acceso a la API de twitter
# ### 1- Registrarse como usuario
# Primero es necesario darse de alta como usuario de twitter en https://twitter.com/signup?lang=es.
# <center>
#     <img src="attachment:9b90db62-d330-40c0-80e7-a59952e40776.png">
# </center>

# %% [markdown]
# ### 2- Registrarse como desarrollador
# Para registrarse como desarrollado hay que ingresar a: https://developer.twitter.com/en/apps.

# %% [markdown]
# <center>
#     <img src="attachment:58a9965e-3b6e-4c24-aa5f-00b349646d77.png">
#     <img src="attachment:158c4469-5842-421e-aaf6-0b3412bbfaa6.png">
#     <img src="attachment:68151b81-78a8-412a-a1dc-c2089abbc582.png">
#     <img src="attachment:23b956ad-b7a2-41fb-aabf-5307e4a79531.png">
#     <img src="attachment:0c332732-c296-4627-8062-cc68ce258e06.png">
#     <img src="attachment:f528aff2-9a6d-4ccf-b95f-0ac613d8e7e9.png">
#     <img src="attachment:4a628f7a-faaf-4e45-898b-ba34663c2432.png">
#     <img src="attachment:e60928ac-d16a-4784-95d9-a78aa5851f23.png">
#     <img src="attachment:fa28ca49-1675-460f-9463-64246491b03f.png">
#     <img src="attachment:8681839b-54b3-481f-bfad-b68e3761f352.png">
#     <img src="attachment:b6aca690-d8db-42f1-8570-cd2516b958cf.png">
# </center>

# %% [markdown]
# ### 3- Dar de alta una aplicación
#
# <center>
#     <img src="attachment:76afe92a-7527-4cb6-8e90-9e36982474a4.png">
#     <img src="attachment:ec46aa88-8900-4239-8f11-c61f46edf167.png">
# </center>

# %% [markdown]
# <center>
#      <a href="https://geduldig.github.io/TwitterAPI/#" title="Documentación">
#     <img src="https://raw.githubusercontent.com/geduldig/TwitterAPI/master/logo.png">
#     </a>
# </center>
#
# Vamos a usar la librería twitterAPI para los ejemplos

# %%
pip install twitterAPI
# Out:
# Note: you may need to restart the kernel to use updated packages.
# El nombre de archivo, el nombre de directorio o la sintaxis de la etiqueta del volumen no son correctos.

# %% [markdown]
# <center>
#     <img src="attachment:91a1d05f-e246-417d-be69-bc4d7b0375b3.png">
# </center>
#
# Hay que reemplazar con las claves de nuestra aplicación que registramos en twitter
# - YOUR_CONSUMER_KEY: API Key
# - YOUR_CONSUMER_SECRET: API Key Secret
# - YOUR_ACCESS_TOKEN: Access Token
# - YOUR_ACCESS_TOKEN_SECRET: Access Token Secret

# %% [markdown]
# ### Buscar tweets
# #### Endpoints
# la API de Twitter abre diferentes canales o niveles de acceso que permiten realizar distintos tipos de búsquedas, por ejemplo tweets históricos, tweets recientes (últimos 7 días), etc. Algunos de estos endpoints se pueden acceder en forma gratuita, y a otros solo se puede acceder si se paga por el uso.
#
# Para más información sobre los endpoints ver: https://developer.twitter.com/en/docs/twitter-api/search-overview
#
#
# Para generar una consulta se debe enviar una query, para más información de cómo construir un query se puede consultar:
# https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterRequestError, TwitterConnectionError
'''
Busca tweets recientes con no más de 7 días de antigüedad (endpoint 'tweets/search/recent')
'''
def buscar_tweets(query):
    try:
        o = TwitterOAuth.read_file()
        api = TwitterAPI(o.consumer_key, o.consumer_secret, o.access_token_key, o.access_token_secret, api_version='2')
        r = api.request('tweets/search/recent', {
            'query':query, 
            'tweet.fields':'author_id',
            'expansions':'author_id'})
        return r

    except TwitterRequestError as e:
        print(e.status_code)
        for msg in iter(e):
            print(msg)

    except TwitterConnectionError as e:
        print(e)

    except Exception as e:
        print(e)

#Todas las palabras separadas por espacios 
QUERY = 'pizza empanadas'
#usuarios @rogerfederer o @RafaelNadal
#QUERY = '@rogerfederer OR @RafaelNadal'
#Tweets de Federer (que no sean retweets)
#QUERY = '@rogerfederer (-is:retweet)'
#tweets de un usuario en particular
#QUERY = 'from: muyinteresante'
r = buscar_tweets(QUERY)
for tweet in r:
    if 'text' in tweet:
        print(tweet["text"])
        print()
# Out:
# Tenía miedo de cagarme de hambre en el laburo así que me traje pizza, dos empanadas, un yogurt, galletas de avena, una banana y un alfajor POR LAS DUDAS NOMÁS
#
# @PabloC74653137 @JuanP630 @oligolds @bromencasa bueno, acá morfamos asado, pizza, milanesas y empanadas, tallarines, peces de mar y río, helado y no nos mandamos la parte.  En serio vive tan para el culo en donde está?
#
# @Fernandagotthe1 Las de pizza son buenas, pero con el pollo de barra duarte deben de quedar unas empanadas riquisimas.
#
# RT @dexterouslysad: Quiero una pizza de empanadas de lomitos
#
# 1 de la mañana recibiendo al delivery con una pizza napolitana y empanadas. Que perdición 😂
#
# Quiero una pizza de empanadas de lomitos
#
# Pizza y empanadas, con una coca cola bien fría y mirando la seleccion. Así siii
#
# Pedimos pizza y a parte le pregunté a la bendi si quería empanadas y me dijo que no, entonces me pedí 3 para mí.
# Adivinen que está comiendo. No tengan hijos.
#
# ...

# %%
import json
print(json.dumps(r.json(), indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "1431424290864439296",
#             "id": "1442573865960579073",
#             "text": "@tutefunado Hay quien come empanadas con pasaa de uva y pizza con anana. Hay gustos para todos"
#         },
#         {
#             "author_id": "1425828457485783048",
#             "id": "1442572662769782785",
#             "text": "RT @diariohoynet: \ud83c\udf55\ud83c\udf03| #Pizza | #Empanadas | #LaPlata |\n\nLlega a la ciudad la \"Noche de la pizza y la empanada\"\n\nEl martes 28 ser\u00e1 el evento\u2026"
#         },
#         {
#             "author_id": "1300594039348105217",
#             "id": "1442569975760228357",
#             "text": "Por fin hice la caca post asado,empanadas, pizza, hamburguesas y postres varios https://t.co/nL2mYsaRGA"
#         },
#         {
#             "author_id": "1449062124",
#             "id": "1442565913568493568",
# ...

# %%
r

# %%
tweets=r.json()["data"]
usuarios=r.json()["includes"]["users"]
      
for tweet in tweets:
    for usuario in usuarios:
        if tweet["author_id"] == usuario["id"]:
            print("@"+usuario["username"],"===>", tweet["text"])
            print()

# %% [markdown]
# ### Flujo en tiempo real
# La API de twitter también nos permite conectarnos a un flujo o stream en tiempo real y filtrar los tweets que están ocurriendo
#
# https://developer.twitter.com/en/docs/tutorials/stream-tweets-in-real-time

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterRequestError, TwitterConnectionError, HydrateType, OAuthType
import json

QUERY = '"pizza" OR "hamburguesa"'
EXPANSIONS = 'author_id,referenced_tweets.id,referenced_tweets.id.author_id,in_reply_to_user_id,attachments.media_keys,attachments.poll_ids,geo.place_id,entities.mentions.username'
TWEET_FIELDS='author_id,conversation_id,created_at,entities,geo,id,lang,public_metrics,source,text'
USER_FIELDS='created_at,description,entities,location,name,profile_image_url,public_metrics,url,username'
def stream_tweets(query, expansions, tweet_fields, user_fields):
    
    try:
        o = TwitterOAuth.read_file()
        api = TwitterAPI(o.consumer_key, o.consumer_secret, auth_type=OAuthType.OAUTH2, api_version='2')

        # ADD STREAM RULES

        r = api.request('tweets/search/stream/rules', {'add': [{'value':QUERY}]})
        print(f'[{r.status_code}] RULE ADDED: {json.dumps(r.json(), indent=2)}\n')
        if r.status_code != 201: exit()

        # GET STREAM RULES

        r = api.request('tweets/search/stream/rules', method_override='GET')
        print(f'[{r.status_code}] RULES: {json.dumps(r.json(), indent=2)}\n')
        if r.status_code != 200: exit()

        # START STREAM

        r = api.request('tweets/search/stream', {
                'expansions': EXPANSIONS,
                'tweet.fields': TWEET_FIELDS,
                'user.fields': USER_FIELDS,
            },
            hydrate_type=HydrateType.APPEND)

        print(f'[{r.status_code}] START...')
        if r.status_code != 200: exit()

        with open('data.json', 'w', encoding='utf-8') as f:
            for item in r:
                print(json.dumps(item, indent=2))
                json.dump(item, f, ensure_ascii=False, indent=4)
                
    except KeyboardInterrupt:
        print('\nDone!')

    except TwitterRequestError as e:
        print(f'\n{e.status_code}')
        for msg in iter(e):
            print(msg)

    except TwitterConnectionError as e:
        print(e)

    except Exception as e:
        print(e)
    
QUERY = '"pizza" OR "burger"'
EXPANSIONS = 'author_id,referenced_tweets.id,referenced_tweets.id.author_id,in_reply_to_user_id,attachments.media_keys,attachments.poll_ids,geo.place_id,entities.mentions.username'
TWEET_FIELDS='author_id,conversation_id,created_at,entities,geo,id,lang,public_metrics,source,text'
USER_FIELDS='created_at,description,entities,location,name,profile_image_url,public_metrics,url,username'
r = stream_tweets(QUERY, EXPANSIONS, TWEET_FIELDS, USER_FIELDS)
# Out:
# [201] RULE ADDED: {
#   "meta": {
#     "sent": "2021-10-08T14:14:47.007Z",
#     "summary": {
#       "created": 0,
#       "not_created": 1,
#       "valid": 0,
#       "invalid": 1
#     }
#   },
#   "errors": [
#     {
#       "value": "\"pizza\" OR \"burger\"",
#       "id": "1446475917660991492",
#       "title": "DuplicateRule",
#       "type": "https://api.twitter.com/2/problems/duplicate-rules"
#     }
#   ]
# }
#
# [200] RULES: {
#   "data": [
#     {
#       "id": "1446475917660991492",
#       "value": "\"pizza\" OR \"burger\""
#     }
#   ],
#   "meta": {
#     "sent": "2021-10-08T14:14:48.033Z",
#     "result_count": 1
#   }
# }
#
# [200] START...
# {
#   "data": {
#     "attachments": {},
#     "author_id": "1034011524417900544",
#     "conversation_id": "1446479163771207683",
#     "created_at": "2021-10-08T14:14:41.000Z",
#     "entities": {
#       "mentions": [
#         {
#           "start": 3,
#           "end": 16,
#           "username": "FrancyArtist",
# ...

# %%
r

# %%
import json
print(json.dumps(r.json(), indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "1046767862331969537",
#             "id": "1446472559399251975",
#             "text": "Ten\u00eda miedo de cagarme de hambre en el laburo as\u00ed que me traje pizza, dos empanadas, un yogurt, galletas de avena, una banana y un alfajor POR LAS DUDAS NOM\u00c1S"
#         },
#         {
#             "author_id": "136265964",
#             "id": "1446462268091273219",
#             "text": "@PabloC74653137 @JuanP630 @oligolds @bromencasa bueno, ac\u00e1 morfamos asado, pizza, milanesas y empanadas, tallarines, peces de mar y r\u00edo, helado y no nos mandamos la parte.  En serio vive tan para el culo en donde est\u00e1?"
#         },
#         {
#             "author_id": "1266303613674106880",
#             "id": "1446454635812818948",
#             "text": "@Fernandagotthe1 Las de pizza son buenas, pero con el pollo de barra duarte deben de quedar unas empanadas riquisimas."
#         },
#         {
# ...

# %%
r

# %%
print(r.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-ceef3140d849> in <module>
# ----> 1 print(r.json())
#
# ~/.local/lib/python3.9/site-packages/TwitterAPI/TwitterAPI.py in json(self, **kwargs)
#     258         :raises: ValueError
#     259         """
# --> 260         return self.response.json(**kwargs)
#     261
#     262     def get_iterator(self):
#
# /usr/lib/python3/dist-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# /usr/lib/python3/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     523             parse_constant is None and object_pairs_hook is None
# ...
